# %%
# %matplotlib inline
import math
import time
import numpy as np
from myPkg import myPlot as d2l

# %%
def normal(x, mu, sigma):
    p = 1 / math.sqrt(2 * math.pi * sigma**2)
    return p * np.exp(-0.5 / sigma**2 * (x - mu)**2)

# %%
# 再次使用numpy进行可视化
x = np.arange(-7, 7, 0.01)

# 均值和标准差对
params = [(0, 1), (0, 2), (3, 1)]
d2l.plot(x, [normal(x, mu, sigma) for mu, sigma in params],
         xlabel='x',
         ylabel='p(x)', figsize=(4.5, 2.5),
         legend=[f'mean {mu}, std {sigma}' for mu, sigma in params])

# %%
def sigmoid(x):
    p = 1/(1+np.exp(-x))
    return p 

def err(x):
    return np.random.randn(1,x.size)*0.1

# %%
# 再次使用numpy进行可视化
x = np.arange(0, 7, 0.05)
params = range(1,5);

d2l.plot(x, [i*sigmoid(x) for i in params], 
         [err(x) for i in params],
         xlabel='Times(s)',
         ylabel='p(x)', figsize=(4.5, 2.5),
         legend=[f'mul {mu}' for mu in params])
d2l.plt.savefig('sigmoid.png', dpi=300)  # Save with 300 DPI

# %%
data=[i*sigmoid(x) for i in params]
shape = np.array(data).shape
shape
# Out:
# (4, 140)

# %%
d2l.plot(x, [data[i] for i in range(shape[0])], 
         [err(x) for i in params],
         xlabel='Times(s)',
         ylabel='p(x)', figsize=(4.5, 2.5),
         legend=[f'mul {mu}' for mu in params])

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_rate = 1000
t,data = d2l.generate_sine_data(num_signals=9, num_samples=1000, sample_rate=1000)

f,y = d2l.fft_analysis(data,sample_rate)

params = range(9)
d2l.plot(t,[data[i] for i in params],
         xlabel='Times(s)',
         ylabel='p(x)', 
         figsize=(4.5, 2.5),
         legend=[f'mul {mu}' for mu in params])

# %%
d2l.plot(f,y, 
         xlabel='Frequency',
         ylabel='p(x)', 
         figsize=(4.5, 2.5),
         xlim=[0,50],
         legend=[f'mul {mu}' for mu in params])

# %%
f,y = d2l.fft_analysis(data.mean(0),sample_rate)
d2l.plot(f,y, 
         xlabel='Frequency',
         ylabel='p(x)', 
         figsize=(4.5, 2.5),
         xlim=[0,50],
         legend=[f'mul {mu}' for mu in params])

# %%
data.ndim
# Out:
# 2

# %%
# !conda install -c conda-forge scienceplots

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

plt.style.use('science')
# Generate the accuracy data for 10 groups
num_groups = 10
time_points,all_accuracies = d2l.generate_multiple_accuracy_data(num_groups=num_groups, num_points=20)
params =range(2)

d2l.plot((time_points+1)/10,
         [all_accuracies[i] for i in params ] ,
         [err(time_points) for i in params],
          xlabel='Time(s)',
         ylabel='Accuracy(%)', 
         
         figsize=(4.5, 2.5),
         xlim=[0.05,2.05],
         legend=[f'S{mu}' for mu in params],
        titles="TRCA"
        )
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001353CF699D0> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\Creator\Anaconda\envs\d2l\lib\site-packages\matplotlib\texmanager.py:233, in TexManager._run_checked_subprocess(self, command, tex, cwd)
#     232 try:
# --> 233     report = subprocess.check_output(
#     234         command, cwd=cwd if cwd is not None else self.texcache,
#     235         stderr=subprocess.STDOUT)
#     236 except FileNotFoundError as exc:
#
# File D:\Creator\Anaconda\envs\d2l\lib\subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425            **kwargs).stdout
#
# ...

# %%
pparam = dict(xlabel='Voltage (mV)', ylabel=r'Current ($\mu$A)')

x = np.linspace(0.75, 1.25, 201)

with plt.style.context(['science']):
    fig, ax = plt.subplots()
    for p in [10, 15, 20, 30, 50, 100]:
        ax.plot(x, model(x, p), label=p)
    ax.legend(title='Order')
    ax.autoscale(tight=True)
    ax.set(**pparam)
    fig.savefig('figures/fig01a.jpg', dpi=300)
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       6 fig, ax = plt.subplots()
#       7 for p in [10, 15, 20, 30, 50, 100]:
# ----> 8     ax.plot(x, model(x, p), label=p)
#       9 ax.legend(title='Order')
#      10 ax.autoscale(tight=True)
#
# NameError: name 'model' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001353CF699D0> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\Creator\Anaconda\envs\d2l\lib\site-packages\matplotlib\texmanager.py:233, in TexManager._run_checked_subprocess(self, command, tex, cwd)
#     232 try:
# --> 233     report = subprocess.check_output(
#     234         command, cwd=cwd if cwd is not None else self.texcache,
# ...
